# %%
import numpy as np  # type: ignore
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("D:\sakshi\data science\cars (1).csv")

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
df.shape
# Out:
# (205, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    object
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(2), int64(5), object(8)
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# body-style            object
# drive-wheels          object
# engine-location       object
# width                float64
# height               float64
# engine-type           object
# engine-size            int64
# horsepower            object
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df["normalized-losses"].loc[df["normalized-losses"]=="?"].count()
# Out:
# 41

# %%
Indexes_with_qustion_mark = df.index[df["normalized-losses"]=="?"]
Indexes_with_qustion_mark
# Out:
# Index([  0,   1,   2,   5,   7,   9,  14,  15,  16,  17,  43,  44,  45,  46,
#         48,  49,  63,  66,  71,  73,  74,  75,  82,  83,  84, 109, 110, 113,
#        114, 124, 126, 127, 128, 129, 130, 131, 181, 189, 191, 192, 193],
#       dtype='int64')

# %%
nl = df["normalized-losses"].loc[df["normalized-losses"] != "?"]

# %%
nlmean = nl.astype(str).astype(int).mean()

# %%
df["normalized-losses"] = df["normalized-losses"].replace("?",nlmean).astype(int)
df["normalized-losses"] = df["normalized-losses"].fillna(df["normalized-losses"].mean())

# %%
df['normalized-losses'].isnull().sum()
# Out:
# 0

# %%
df["normalized-losses"]
# Out:
# 0      122
# 1      122
# 2      122
# 3      164
# 4      164
#       ...
# 200     95
# 201     95
# 202     95
# 203     95
# 204     95
# Name: normalized-losses, Length: 205, dtype: int32

# %%
df
# Out:
#      symboling  normalized-losses         make fuel-type   body-style  \
# 0            3                122  alfa-romero       gas  convertible
# 1            3                122  alfa-romero       gas  convertible
# 2            1                122  alfa-romero       gas    hatchback
# 3            2                164         audi       gas        sedan
# 4            2                164         audi       gas        sedan
# ..         ...                ...          ...       ...          ...
# 200         -1                 95        volvo       gas        sedan
# 201         -1                 95        volvo       gas        sedan
# 202         -1                 95        volvo       gas        sedan
# 203         -1                 95        volvo    diesel        sedan
# 204         -1                 95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
df["price"].loc[df["price"]=="?"].count()
# Out:
# 0

# %%
Indexes_with_qustion_mark = df.index[df["horsepower"] == "?"]
Indexes_with_qustion_mark
# Out:
# Index([130, 131], dtype='int64')

# %%
nl = df["horsepower"].loc[df["horsepower"] != "?" ]

# %%
nlm = nl.astype(str).astype(int).mean()

# %%
df["horsepower"] = df["horsepower"].replace("?",nlm).astype(int)
df["horsepower"] = df["horsepower"].fillna(df["horsepower"].mean())

# %%
df["horsepower"].isnull().sum()
# Out:
# 0

# %%
df["horsepower"]
# Out:
# 0      111
# 1      111
# 2      154
# 3      102
# 4      115
#       ...
# 200    114
# 201    160
# 202    134
# 203    106
# 204    114
# Name: horsepower, Length: 205, dtype: int32

# %%
df
# Out:
#      symboling  normalized-losses         make fuel-type   body-style  \
# 0            3                122  alfa-romero       gas  convertible
# 1            3                122  alfa-romero       gas  convertible
# 2            1                122  alfa-romero       gas    hatchback
# 3            2                164         audi       gas        sedan
# 4            2                164         audi       gas        sedan
# ..         ...                ...          ...       ...          ...
# 200         -1                 95        volvo       gas        sedan
# 201         -1                 95        volvo       gas        sedan
# 202         -1                 95        volvo       gas        sedan
# 203         -1                 95        volvo    diesel        sedan
# 204         -1                 95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    int32
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    int32
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(2), int32(2), int64(5), object(6)
# ...

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df.describe()
# Out:
#         symboling  normalized-losses       width      height  engine-size  \
# count  205.000000         205.000000  205.000000  205.000000   205.000000
# mean     0.834146         122.000000   65.907805   53.724878   126.907317
# std      1.245307          31.681008    2.145204    2.443522    41.642693
# min     -2.000000          65.000000   60.300000   47.800000    61.000000
# 25%      0.000000         101.000000   64.100000   52.000000    97.000000
# 50%      1.000000         122.000000   65.500000   54.100000   120.000000
# 75%      2.000000         137.000000   66.900000   55.500000   141.000000
# max      3.000000         256.000000   72.300000   59.800000   326.000000
#
#        horsepower    city-mpg  highway-mpg         price
# count  205.000000  205.000000   205.000000    205.000000
# mean   104.253659   25.219512    30.751220  13227.478049
# std     39.519219    6.542142     6.886443   7902.651615
# min     48.000000   13.000000    16.000000   5118.000000
# ...

# %%
plt.figure(figsize=(14,8))
sns.boxplot(data=df,y="make",x="price")
# Out:
# <Axes: xlabel='price', ylabel='make'>

# %%
df[(df["make"]=="dodge")& (df["price"]>12000)]
# Out:
#     symboling  normalized-losses   make fuel-type body-style drive-wheels  \
# 29          3                145  dodge       gas  hatchback          fwd
#
#    engine-location  width  height engine-type  engine-size  horsepower  \
# 29           front   66.3    50.2         ohc          156         145
#
#     city-mpg  highway-mpg  price
# 29        19           24  12964

# %%
df.drop(29,inplace=True)

# %%
df[(df["make"]=="honda")&(df["price"]>12000)]
# Out:
#     symboling  normalized-losses   make fuel-type body-style drive-wheels  \
# 41          0                 85  honda       gas      sedan          fwd
#
#    engine-location  width  height engine-type  engine-size  horsepower  \
# 41           front   65.2    54.1         ohc          110         101
#
#     city-mpg  highway-mpg  price
# 41        24           28  12945

# %%
df.drop(41,inplace=True)

# %%
df[(df["make"]=="isuzu")&(df["price"]>21000)]
# Out:
#     symboling  normalized-losses   make fuel-type body-style drive-wheels  \
# 45          0                122  isuzu       gas      sedan          fwd
#
#    engine-location  width  height engine-type  engine-size  horsepower  \
# 45           front   63.6    52.0         ohc           90          70
#
#     city-mpg  highway-mpg  price
# 45        38           43  23000

# %%
df.drop(45,inplace=True)

# %%
df[(df["make"]=="mitsubishi")&(df["price"]>14000)]
# Out:
#     symboling  normalized-losses        make fuel-type body-style  \
# 83          3                122  mitsubishi       gas  hatchback
# 84          3                122  mitsubishi       gas  hatchback
#
#    drive-wheels engine-location  width  height engine-type  engine-size  \
# 83          fwd           front   66.3    50.2         ohc          156
# 84          fwd           front   66.3    50.2         ohc          156
#
#     horsepower  city-mpg  highway-mpg  price
# 83         145        19           24  14869
# 84         145        19           24  14489

# %%
df.drop([83,84],inplace=True)

# %%
df[(df["make"]=="plymouth")&(df["price"]>11000)]
# Out:
#      symboling  normalized-losses      make fuel-type body-style drive-wheels  \
# 124          3                122  plymouth       gas  hatchback          rwd
#
#     engine-location  width  height engine-type  engine-size  horsepower  \
# 124           front   66.3    50.2         ohc          156         145
#
#      city-mpg  highway-mpg  price
# 124        19           24  12764

# %%
df.drop(124,inplace=True)

# %%
df[(df["make"]=="toyota")&(df["price"]>15000)]
# Out:
#      symboling  normalized-losses    make fuel-type   body-style drive-wheels  \
# 172          2                134  toyota       gas  convertible          rwd
# 178          3                197  toyota       gas    hatchback          rwd
# 179          3                197  toyota       gas    hatchback          rwd
# 180         -1                 90  toyota       gas        sedan          rwd
# 181         -1                122  toyota       gas        wagon          rwd
#
#     engine-location  width  height engine-type  engine-size  horsepower  \
# 172           front   65.6    53.0         ohc          146         116
# 178           front   67.7    52.0        dohc          171         161
# 179           front   67.7    52.0        dohc          171         161
# 180           front   66.5    54.1        dohc          171         156
# 181           front   66.5    54.1        dohc          161         156
#
#      city-mpg  highway-mpg  price
# ...

# %%
df.drop([172,178,179,180,181],inplace=True)

# %%
plt.figure(figsize=(14,8))
sns.boxplot(data=df,y="make",x="price")
# Out:
# <Axes: xlabel='price', ylabel='make'>

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['make']=le.fit_transform(df['make'])
df['fuel-type']=le.fit_transform(df['fuel-type'])
df['body-style']=le.fit_transform(df['body-style'])
df['drive-wheels']=le.fit_transform(df['drive-wheels'])
df['engine-location']=le.fit_transform(df['engine-location'])
df['engine-type']=le.fit_transform(df['engine-type'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 194 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          194 non-null    int64
#  1   normalized-losses  194 non-null    int32
#  2   make               194 non-null    int64
#  3   fuel-type          194 non-null    int64
#  4   body-style         194 non-null    int64
#  5   drive-wheels       194 non-null    int64
#  6   engine-location    194 non-null    int64
#  7   width              194 non-null    float64
#  8   height             194 non-null    float64
#  9   engine-type        194 non-null    int64
#  10  engine-size        194 non-null    int64
#  11  horsepower         194 non-null    int32
#  12  city-mpg           194 non-null    int64
#  13  highway-mpg        194 non-null    int64
#  14  price              194 non-null    int64
# dtypes: float64(2), int32(2), int64(11)
# memory usage: 22.7 KB
